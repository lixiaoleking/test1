# %% [markdown]
# # 数据

# %%
detail = pd.read_excel(r'D:\weichat_file\WeChat Files\wxid_yn1yzweuijyn22\FileStorage\File\2021-08\车联网话单列表.xlsx',sep=',', encoding='utf-8')

# %% [markdown]
# ## 数据描述

# %%
detail.info #376670 rows x 20 columns
# Out:
# <bound method DataFrame.info of                    imsi         msisdn              imei    apn  \
# 0       460111111970586  1064910005037  8614760333468200  ctlte
# 1       460111111970586  1064910005037  8614760333468200  ctlte
# 2       460111111970586  1064910005037  8614760333468200  ctlte
# 3       460111111970586  1064910005037  8614760333468200  ctlte
# 4       460111111970586  1064910005037  8614760333468200  ctlte
# 5       460111111970586  1064910005037  8614760333468200  ctlte
# 6       460111111970586  1064910005037  8614760333468200  ctlte
# 7       460111111970586  1064910005037  8614760333468200  ctlte
# 8       460111111970586  1064910005037  8614760333468200  ctlte
# 9       460111111970586  1064910005037  8614760333468200  ctlte
# 10      460111111970586  1064910005037  8614760333468200  ctlte
# 11      460111111970586  1064910005037  8614760333468200  ctlte
# 12      460111111970586  1064910005037  8614760333468200  ctlte
# ...

# %%
detail.columns  # 列名
# Out:
# Index(['imsi', 'msisdn', 'imei', 'apn', 'sna_ipbinv4', 'recordopeningtime',
#        'main_userlocation_hex', 'losd_userlocation_hex', 'starttime',
#        'stoptime', 'duration', 'losd_timeoffirstusage', 'losd_timeoflastusage',
#        'losd_datavolumefbcuplink', 'losd_datavolumefbcdownlink', 'onkey',
#        'use_province', 'use_city', 'bs_name', 'yyyymmdd'],
#       dtype='object')

# %% [markdown]
# ## 100个卡号在15天中每一天的话单数

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
#detail["yyyymmdd"].value_counts().plot.bar()
plt.figure(figsize=(13,8))   #图的宽和长，单位为inch
sns.countplot(detail["yyyymmdd"], palette="Set3")

# %% [markdown]
# ## 100个卡号 话单量

# %%
#detail["yyyymmdd"].value_counts().plot.bar()
plt.figure(figsize=(10,15))   #图的宽和长，单位为inch
sns.countplot(y = detail["msisdn"], palette="Set3")

# %%
detail["msisdn"].value_counts()
# Out:
# 1064911082314    32833
# 1064910962348    31584
# 1064910107214    23538
# 1064910087011    21379
# 1064910021934    21317
# 1064910082234    20275
# 1064910101914    18070
# 1064910019216    17212
# 1064910094456    13787
# 1064910777436    10813
# 1064910017917    10357
# 1064910029075     8361
# 1064910757393     7901
# 1064910094854     7849
# 1064910105879     7576
# 1064910005037     7387
# 1064910083412     6721
# 1064910032816     6368
# 1064910055631     4767
# 1064910610839     4572
# 1064910748617     4128
# 1064911125605     3684
# 1064910094618     3097
# 1064910806712     2863
# 1064910637592     2835
# 1064911169244     2774
# 1064910090133     2629
# 1064910614991     2560
# 1064910919776     2514
# 1064910849699     2387
#                  ...
# 1064911082375      740
# 1064911111948      739
# 1064910554073      721
# 1064910104231      706
# 1064910628916      705
# 1064910101136      704
# 1064910548333      699
# 1064910934248      645
# 1064911148263      587
# ...

# %% [markdown]
# ## 取话单数最多的进行分析

# %%
detail1 = detail[detail['msisdn'].isin(['1064910962348'])]
detail1.to_excel("1064910962348.xlsx")

# %%
detail1 = detail[detail['msisdn'].isin(['1064910107214'])]
detail1.to_excel("1064910107214.xlsx")

# %% [markdown]
# ### 分析 1064910962348

# %%
L1064910962348 = pd.read_excel(r'1064910962348.xlsx',sep=',', encoding='utf-8')
L1064910962348['bs_name'].value_counts()
# Out:
# \N                        16282
# SZL2ZTB吴中_金山门诊            11806
# testSZL2ZTD吴中_天平模块BBU1     1770
# SZLAZTB吴中_金山丽格大酒店          1234
# SZL2ZTD吴中_金山模块BBU1          351
# SZL2ZTD吴中_中华园大酒店            104
# testSZL2ZTD吴中_金山模块BBU2       37
# Name: bs_name, dtype: int64

# %%
L1064910107214 = pd.read_excel(r'1064910107214.xlsx',sep=',', encoding='utf-8')
L1064910107214['bs_name'].value_counts()
# Out:
# \N                                6653
# R-曹县-盐务局-宏站-F-L-H-38086           2860
# R-曹县-广电-混合-F-H-H-64925            2300
# R-曹县-回中-混合-F-H-H-38085            1282
# R-曹县-邮政局-宏站-F-R-H-380EE            793
# R-曹县-回中-宏站-F-R-H-382C6             684
# R-曹县-蓬建建工-混合-F-H-H-381CC           623
# R-曹县-澳洲大酒店-混合-F-H-H-380B3          564
# R-曹县-聋哑学校-宏站-F-L-H-380B6           452
# R-曹县-邮政局-宏站-F-L-H-64949            398
# R-曹县-畜牧局-宏站-F-L-H-DBC83-800M       379
# R-曹县-畜牧局-混合-F-H-H-64912            334
# R-曹县-郑庄-宏站-F-L-H-380B9             318
# R-曹县-兵马楼-宏站-F-L-H-380E7            311
# R-曹县-马山庄-宏站-F-H-H-380EA            275
# R-曹县-技工学校-宏站-F-R-H-380B2           241
# NCQ0031206财经学校                     220
# R-曹县-郑庄邻庙集-宏站-F-L-H-DBDD6-800M     214
# R-曹县-辉煌电力-宏站-F-R-H-6491C           205
# R-曹县-辉煌电力-宏站-F-H-H-64916           196
# R-曹县-倪集-宏站-F-L-H-38389             186
# R-曹县-青固集-宏站-F-L-H-381D1            161
# R-曹县-倪集王吕集-宏站-F-L-H-DBC92-800M     147
# R-曹县-民立中学-宏站-F-L-H-3809F           145
# ...
